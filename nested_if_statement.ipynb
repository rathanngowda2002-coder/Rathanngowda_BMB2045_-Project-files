# %%
Rathan N Gowda

# %%
PH=float(input("enter the ph value:"))
if PH<5.5:
 print("acidic")
elif PH<7.5:
  print("neutral")
elif PH>7.5:
  print("alkaline")
else:
  print("higly alkaline")
# Out:
# enter the ph value:9
# alkaline

# %%
#list of crops
crops=["rice","wheat","maize"]
#display crops
print(" number of crops grown in field")
crops.append("sugarcane")
#addition new crop
print(crops)
# Out:
#  number of crops grown in field
# ['rice', 'wheat', 'maize', 'sugarcane']

# %%
#list of crops
crops=["rice","wheat","maize"]
#display crops
print(" number of crops grown in field")
crops.append("sugarcane")
#addition new crop
print(crops)
#display number of crops
print("number of crops grown:",len(crops))
# Out:
#  number of crops grown in field
# ['rice', 'wheat', 'maize', 'sugarcane']
# number of crops grown: 4

# %%
crops.insert(1,"sugarcane")
print(crops)
print("number of crops grown:",len(crops))
# Out:
# ['rice', 'sugarcane', 'sugarcane', 'wheat', 'maize', 'sugarcane']
# number of crops grown: 6

# %%
#remove last crop
crops.pop()
