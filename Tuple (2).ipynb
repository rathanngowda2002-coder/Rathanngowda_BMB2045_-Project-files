# %% [markdown]
# Rathan N Gowda

# %%
T=(1,2,"ANU")
print(type(T))
print("Number of elements",len(T))
print(T)
# Out:
# <class 'tuple'>
# Number of elements 3
# (1, 2, 'ANU')

# %%
T=([4,5,6,"ANU"])
print(type(T))
# Out:
# <class 'list'>

# %% [markdown]
# **with , it is tuple**

# %%
T=([4,5,6,"AMMU"])
i=0
while i<len(T):
  print(T[i])
  i+=1
# Out:
# 4
# 5
# 6
# AMMU

# %%
for i in range(len(T)):
 print(T[i])
# Out:
# 4
# 5
# 6
# AMMU

# %% [markdown]
# **u can take anything other than i**

# %%
for s in T:
  print(s)
# Out:
# 4
# 5
# 6
# AMMU

# %%
T=(1,2,3,"AMMU")
print(T[1])
print(T[0])
print(T[2])
print("T[3]",T[3])
# Out:
# 2
# 1
# 3
# T[3] AMMU

# %%
T=(1,2,3,"AMMU")
print(T[1:2])
print(T[1:])
print(T[:2])
print(T[:-1])
print(T[-3:-1])
print(T[-3:])
print(T[-4:-1])
# Out:
# (2,)
# (2, 3, 'AMMU')
# (1, 2)
# (1, 2, 3)
# (2, 3)
# (2, 3, 'AMMU')
# (1, 2, 3)

# %%
T=(1,2,3,"AMMU")
print(T[::-1])
print(T[::1])
print(T[0::])
print(T[::-2])
print(T[::2])
print(T[::3])
print(T[1::])
# Out:
# ('AMMU', 3, 2, 1)
# (1, 2, 3, 'AMMU')
# (1, 2, 3, 'AMMU')
# ('AMMU', 2)
# (1, 3)
# (1, 'AMMU')
# (2, 3, 'AMMU')

# %%
T[::1]
# Out:
# (1, 2, 3, 'AMMU')

# %% [markdown]
# **Adding element to tuple**

# %%
T=(1,2,3,4,5)
print(T)
T[5]=6
print(T)
# Out:
# (1, 2, 3, 4, 5)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2912/593286683.py in <cell line: 0>()
#       1 T=(1,2,3,4,5)
#       2 print(T)
# ----> 3 T[5]=6
#       4 print(T)
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# **Append,pop**

# %%
T=(1,2,3,4,5)
T1=list(T)
T1.append(9.8)
print(T1)
T1.pop()
T=tuple(T1)
print("T=",T)
print("After add",T)

# %% [markdown]
# **Insert**

# %%
T1.insert(2,"AMMU")
print(T1)

# %%
T1.remove("AMMU")
print("T1",T1)

# %%
del T1[2]
print(T1)
print(type(T1))
print(type(T))
print("sum",sum(T1))

# %% [markdown]
# **SUM,MAX,MIN**

# %%
T=(1,2,3,4,5)
print("sum",sum(T))
print("max",max(T))
print("min",min(T))
print(len(T))
print(T.count(2))       #to count how many times 2 in T
print(T.index(1))       #to find index of 1

# %%
print("4 in T is",4 in T)
print("6 in T is",6 in T)
# Out:
# 4 in T is True
# 6 in T is False

# %%
print("max of T is",max(T))
print("min of T is",min(T))
# Out:
# max of T is 5
# min of T is 1

# %% [markdown]
# **+ is concatenation operator**

# %%
T1=(1,2,3)
T2=(5,6,7)
T3=T1+T2
print(T3)
# Out:
# (1, 2, 3, 5, 6, 7)

# %%
T4=T1+T2+T3
print(T4)
# Out:
# (1, 2, 3, 5, 6, 7, 1, 2, 3, 5, 6, 7)

# %%
T3=T1[1:2]+T2[1:3]     #T1 1 is 2,2 is -1=1         #T2 1 is 6 and 3 will be -1 that is 7
print("T3",T3)
# Out:
# T3 (2, 6, 7)

# %% [markdown]
# **INDEX**

# %%
T=(1,2,3,4,5)
print("Index of 2 in T is",T.index(2))
print(T.index(1))
# Out:
# Index of 2 in T is 1
# 0

# %% [markdown]
# **COUNT**

# %%
T=(1,2,3,4,5,6,2,2,2)
print(T.count(2))
# Out:
# 4

# %% [markdown]
# **To find id of list**

# %% [markdown]
# same id after append 4 also

# %%
l1=[1,2,3]
print(id(l1))
l1.append(4)
print(id(l1))
# Out:
# 136032815104384
# 136032815104384

# %%
l1.append(3)
print(id(l1))
# Out:
# 136032815104384

# %% [markdown]
# **To find id of set**

# %%
s={1,2,3}
print(id(s))
# Out:
# 136032814781984

# %% [markdown]
# **string is a immutable datatype,a and a have different id for each**

# %%
a="GKVK"
print(id(a))
a=a+"university"
print(id(a))
print("a",a)
# Out:
# 136032815139120
# 136032815548592
# a GKVKuniversity

# %%
s="python"
print(id(s))
s=s+"3"
print(id(s))
s="python"
s[0]="j"
# Out:
# 136033381055440
# 136032814866688
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2912/3500888677.py in <cell line: 0>()
#       4 print(id(s))
#       5 s="python"
# ----> 6 s[0]="j"
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# **integer id is immutable**

# %%
x=10
y=x
print(id(x))
print(id(y))
x=x+20
print(id(x))
print(id(y))
