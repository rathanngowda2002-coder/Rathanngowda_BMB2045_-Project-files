# %% [markdown]
# Rathan N Gowda

# %%
crops=["rice","maize","chickpea"]
#display number of crops grown in field
print("number of crops grown:",len(crops))
# Out:
# number of crops grown: 3

# %%
#list of crops
crops=["rice","maize","chickpea"]
#display number of crops grown in field
print("number of crops grown:",len(crops))
# Out:
# number of crops grown: 3

# %%
crops.append("beans")
print("number of crops grown:",len(crops))
# Out:
# number of crops grown: 4

# %%
#list of soil moistures in percentage
soil_moisture=[45,60,30,55,40]
#display moisture levels
print("soil moisture levels in different fields:")
for moisture in soil_moisture:
  print(f"{moisture}%")
# Out:
# soil moisture levels in different fields:
# 45%
# 60%
# 30%
# 55%
# 40%

# %%
crops=["rice","wheat","millet","maize","pulses"]
water_need = [50,100,150,200,250]
print(len(crops))
print("range",range(len(crops)))
print("crops and water_need:")
for i in range(len(crops)):
 print(f"{crops[i]}: {water_need[i]}")
# Out:
# 5
# range range(0, 5)
# crops and water_need:
# rice: 50
# wheat: 100
# millet: 150
# maize: 200
# pulses: 250
